# %%
import pandas as pd
# Out:
# C:\Users\chado\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('step1_df.csv')
df.head(20)
# Out:
#     Unnamed: 0                                        listing_url       brand  \
# 0            0  https://www.dubizzle.com.eg/en/ad/%D8%A8%D9%8A...         BMW
# 1            1  https://www.dubizzle.com.eg/en/ad/%D9%87%D9%8A...     Hyundai
# 2            2  https://www.dubizzle.com.eg/en/ad/%D9%81%D9%88...  Volkswagen
# 3            3  https://www.dubizzle.com.eg/en/ad/citroen-ds4-...     Citroen
# 4            4  https://www.dubizzle.com.eg/en/ad/%D9%87%D9%8A...     Hyundai
# 5            5  https://www.dubizzle.com.eg/en/ad/renault-flue...     Renault
# 6            6  https://www.dubizzle.com.eg/en/ad/bmw-x6-m60-2...         BMW
# 7            7  https://www.dubizzle.com.eg/en/ad/%D8%A8%D9%8A...         BMW
# 8            8  https://www.dubizzle.com.eg/en/ad/chevrolet-av...   Chevrolet
# 9            9  https://www.dubizzle.com.eg/en/ad/%D8%B9%D8%B1...        Fiat
# 10          10  https://www.dubizzle.com.eg/en/ad/%D8%A8%D9%8A...     Peugeot
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0                                        listing_url  \
# 0              0  https://www.dubizzle.com.eg/en/ad/%D8%A8%D9%8A...
# 1              1  https://www.dubizzle.com.eg/en/ad/%D9%87%D9%8A...
# 2              2  https://www.dubizzle.com.eg/en/ad/%D9%81%D9%88...
# 3              3  https://www.dubizzle.com.eg/en/ad/citroen-ds4-...
# 4              4  https://www.dubizzle.com.eg/en/ad/%D9%87%D9%8A...
# ...          ...                                                ...
# 3399        3399  https://www.dubizzle.com.eg/en/ad/mercedes-ben...
# 3400        3400  https://www.dubizzle.com.eg/en/ad/%D8%B3%D9%8A...
# 3401        3401  https://www.dubizzle.com.eg/en/ad/mercedes-c18...
# 3402        3402  https://www.dubizzle.com.eg/en/ad/2026-%D8%A8%...
# 3403        3403  https://www.dubizzle.com.eg/en/ad/mercedes-ben...
#
#               brand     model    year fuel_type transmission  body_type  \
# ...

# %%
df.groupby(['brand','model']).size().reset_index()
# Out:
#             brand      model   0
# 0      Alfa Romeo        156   1
# 1      Alfa Romeo     Tonale   1
# 2    Aston Martin         DB   1
# 3            Audi         A3  10
# 4            Audi         A4   8
# ..            ...        ...  ..
# 576         Zeekr        001   1
# 577         Zeekr        007   1
# 578         Zeekr         7X   7
# 579         Zeekr          X   1
# 580         Zotye  Explosion   1
#
# [581 rows x 3 columns]

# %%
df[['brand','model']].value_counts().reset_index().sort_values(by = 'count', ascending = False).head(10)
# Out:
#            brand     model  count
# 0  Mercedes-Benz      C180    122
# 1         Nissan     Sunny     58
# 2            Kia  Sportage     55
# 3  Mercedes-Benz      E200     50
# 4  Mercedes-Benz      C200     48
# 5         Toyota   Corolla     47
# 6      Chevrolet     Optra     45
# 7        Renault     Logan     44
# 8  Mercedes-Benz   GLC 300     42
# 9         Daewoo     Lanos     42

# %%
df[['brand']].value_counts().reset_index().sort_values(by = 'count', ascending = False).head(10)
# Out:
#            brand  count
# 0  Mercedes-Benz    463
# 1        Hyundai    199
# 2            BMW    195
# 3            Kia    167
# 4           Fiat    152
# 5        Renault    150
# 6      Chevrolet    150
# 7           Opel    123
# 8     Volkswagen    115
# 9         Nissan    114

# %%
df[['model']].value_counts().reset_index().sort_values(by = 'count', ascending = False).head(10)
# Out:
#       model  count
# 0      C180    122
# 1     Lanos     82
# 2     Sunny     58
# 3  Sportage     55
# 4      E200     50
# 5      C200     48
# 6   Corolla     47
# 7     Optra     45
# 8     Logan     44
# 9   GLC 300     42

# %%
df[['year']].value_counts().reset_index().sort_values(by = 'count', ascending = False).head(10)
# Out:
#      year  count
# 0  2026.0    472
# 1  2025.0    360
# 2  2024.0    214
# 3  2022.0    163
# 4  2020.0    157
# 5  2021.0    156
# 6  2019.0    147
# 7  2023.0    123
# 8  2015.0    111
# 9  2008.0    103

# %%
df[['body_type']].value_counts().reset_index().sort_values(by = 'count', ascending = False).head(10)
# Out:
#         body_type  count
# 0           Sedan   1744
# 1             SUV    758
# 2       Hatchback    473
# 3             4X4    122
# 4  Sports / Coupe     88
# 5          Estate     48
# 6       Van / Bus     34
# 7     Convertible     30
# 8          Pickup     27
# 9             MPV     18
